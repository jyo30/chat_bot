# %%
# importing all the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb
import sklearn.metrics as sm
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
df = pd.read_csv('dummyinvoice.csv')
df
# Out:
#      cust_number Invoice_No  invoice_create_date  due_in_date  \
# 0         JO0001       INV1             20200203     20200213
# 1         JO0002       INV2             20190726     20190808
# 2         JO0003       INV3             20190306     20190324
# 3         JO0004       INV4             20190912     20191002
# 4         JO0005       INV5             20190913     20190928
# ...          ...        ...                  ...          ...
# 1198      JO0009    INV1199             20191207     20191222
# 1199      JO0010    INV1200             20190313     20190328
# 1200      JO0001    INV1201             20200211     20200226
# 1201      JO0002    INV1202             20200109     20200124
# 1202      JO0003    INV1203             20191111     20191215
#
#             clear_date  Invoice Amount  Due_Amount   status
# 0     14-02-2020 00:00           15000       12500  Partial
# 1     01-08-2019 00:00           20000       17000  Partial
# 2     18-03-2019 00:00           25000       21500  Partial
# 3     02-10-2019 00:00           30000       30000    Fully
# 4     24-09-2019 00:00           35000       30500  Partial
# ...                ...             ...         ...      ...
# 1198  17-12-2019 00:00           55000       55000    Fully
# 1199  28-03-2019 00:00           60000       50500  Partial
# 1200  26-02-2020 00:00           65000       62500  Partial
# 1201  24-01-2020 00:00           70000       67000  Partial
# 1202  13-12-2019 00:00           75000       71500  Partial
#
# [1203 rows x 8 columns]

# %% [markdown]
# # preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1203 entries, 0 to 1202
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   cust_number          1203 non-null   object
#  1   Invoice_No           1203 non-null   object
#  2   invoice_create_date  1203 non-null   int64
#  3   due_in_date          1203 non-null   int64
#  4   clear_date           1203 non-null   object
#  5   Invoice Amount       1203 non-null   int64
#  6   Due_Amount           1203 non-null   int64
#  7   status               1203 non-null   object
# dtypes: int64(4), object(4)
# memory usage: 75.3+ KB

# %%
df.isnull().sum()
# Out:
# cust_number            0
# Invoice_No             0
# invoice_create_date    0
# due_in_date            0
# clear_date             0
# Invoice Amount         0
# Due_Amount             0
# status                 0
# dtype: int64

# %% [markdown]
# # Date-Time Conversion

# %%
from datetime import datetime

# %%
df['clear_date']=pd.to_datetime(df['clear_date'],infer_datetime_format=True)
df['clear_date'].head()
# Out:
# 0   2020-02-14
# 1   2019-08-01
# 2   2019-03-18
# 3   2019-10-02
# 4   2019-09-24
# Name: clear_date, dtype: datetime64[ns]

# %%
df['due_in_date']=pd.to_datetime(df['due_in_date'],format='%Y%m%d')
df['due_in_date'].head()
# Out:
# 0   2020-02-13
# 1   2019-08-08
# 2   2019-03-24
# 3   2019-10-02
# 4   2019-09-28
# Name: due_in_date, dtype: datetime64[ns]

# %%
df['invoice_create_date']=pd.to_datetime(df['invoice_create_date'],format='%Y%m%d')
df['invoice_create_date'].head()
# Out:
# 0   2020-02-03
# 1   2019-07-26
# 2   2019-03-06
# 3   2019-09-12
# 4   2019-09-13
# Name: invoice_create_date, dtype: datetime64[ns]

# %%
df.head()
# Out:
#   cust_number Invoice_No invoice_create_date due_in_date clear_date  \
# 0      JO0001       INV1          2020-02-03  2020-02-13 2020-02-14
# 1      JO0002       INV2          2019-07-26  2019-08-08 2019-08-01
# 2      JO0003       INV3          2019-03-06  2019-03-24 2019-03-18
# 3      JO0004       INV4          2019-09-12  2019-10-02 2019-10-02
# 4      JO0005       INV5          2019-09-13  2019-09-28 2019-09-24
#
#    Invoice Amount  Due_Amount   status
# 0           15000       12500  Partial
# 1           20000       17000  Partial
# 2           25000       21500  Partial
# 3           30000       30000    Fully
# 4           35000       30500  Partial

# %%
df.dropna(axis=1,how='all',inplace=True)
df.shape
# Out:
# (1203, 8)

# %%
df.dropna(axis=0,subset=['Invoice_No'],inplace=True)
df.reset_index(drop=True,inplace=True)
df.shape
df
# Out:
#      cust_number Invoice_No invoice_create_date due_in_date clear_date  \
# 0         JO0001       INV1          2020-02-03  2020-02-13 2020-02-14
# 1         JO0002       INV2          2019-07-26  2019-08-08 2019-08-01
# 2         JO0003       INV3          2019-03-06  2019-03-24 2019-03-18
# 3         JO0004       INV4          2019-09-12  2019-10-02 2019-10-02
# 4         JO0005       INV5          2019-09-13  2019-09-28 2019-09-24
# ...          ...        ...                 ...         ...        ...
# 1198      JO0009    INV1199          2019-12-07  2019-12-22 2019-12-17
# 1199      JO0010    INV1200          2019-03-13  2019-03-28 2019-03-28
# 1200      JO0001    INV1201          2020-02-11  2020-02-26 2020-02-26
# 1201      JO0002    INV1202          2020-01-09  2020-01-24 2020-01-24
# 1202      JO0003    INV1203          2019-11-11  2019-12-15 2019-12-13
#
#       Invoice Amount  Due_Amount   status
# 0              15000       12500  Partial
# 1              20000       17000  Partial
# 2              25000       21500  Partial
# 3              30000       30000    Fully
# 4              35000       30500  Partial
# ...              ...         ...      ...
# 1198           55000       55000    Fully
# 1199           60000       50500  Partial
# 1200           65000       62500  Partial
# 1201           70000       67000  Partial
# 1202           75000       71500  Partial
#
# [1203 rows x 8 columns]

# %%
 for cols in df.columns:   
    print(f"{cols} - {df[f'{cols}'].nunique()}")
# Out:
# cust_number - 10
# Invoice_No - 1203
# invoice_create_date - 375
# due_in_date - 391
# clear_date - 295
# Invoice Amount - 18
# Due_Amount - 177
# status - 2

# %%
unique_cols =  [x for x in df.columns if df[x].nunique()==1] 
print(unique_cols)
df.drop(unique_cols,axis=1,inplace=True)
df.columns
# Out:
# []
# Index(['cust_number', 'Invoice_No', 'invoice_create_date', 'due_in_date',
#        'clear_date', 'Invoice Amount', 'Due_Amount', 'status'],
#       dtype='object')

# %%
df.isnull().any()
# Out:
# cust_number            False
# Invoice_No             False
# invoice_create_date    False
# due_in_date            False
# clear_date             False
# Invoice Amount         False
# Due_Amount             False
# status                 False
# dtype: bool

# %%
df['delay']=(df['clear_date']-df['due_in_date']).dt.days

# %%
df.sort_values(by='invoice_create_date',inplace=True) # sorting in ascending order by document_create_date.1
df
# Out:
#      cust_number Invoice_No invoice_create_date due_in_date clear_date  \
# 507       JO0008     INV508          2018-12-30  2019-02-03 2019-03-01
# 221       JO0002     INV222          2018-12-30  2019-01-14 2019-01-09
# 1099      JO0010    INV1100          2018-12-31  2019-01-15 2019-01-10
# 817       JO0008     INV818          2018-12-31  2019-02-01 2019-02-04
# 568       JO0009     INV569          2019-01-02  2019-01-17 2019-01-14
# ...          ...        ...                 ...         ...        ...
# 1092      JO0003    INV1093          2020-02-26  2020-03-12 2020-03-12
# 123       JO0004     INV124          2020-02-26  2020-03-12 2020-03-16
# 346       JO0007     INV347          2020-02-26  2020-03-12 2020-03-10
# 22        JO0003      INV23          2020-02-26  2020-03-12 2020-03-09
# 69        JO0010      INV70          2020-02-26  2020-03-12 2020-03-09
#
#       Invoice Amount  Due_Amount   status  delay
# 507            85000       85000    Fully     26
# 221            15000       15000    Fully     -5
# 1099           70000       65500  Partial     -5
# 817            20000       14000  Partial      3
# 568            50000       41000  Partial     -3
# ...              ...         ...      ...    ...
# 1092           35000       26500  Partial      0
# 123            35000       35000    Fully      4
# 346            45000       42000  Partial     -2
# 22             40000       34000  Partial     -3
# 69             20000       13000  Partial     -3
#
# [1203 rows x 9 columns]

# %%
df.head()
# Out:
#      cust_number Invoice_No invoice_create_date due_in_date clear_date  \
# 507       JO0008     INV508          2018-12-30  2019-02-03 2019-03-01
# 221       JO0002     INV222          2018-12-30  2019-01-14 2019-01-09
# 1099      JO0010    INV1100          2018-12-31  2019-01-15 2019-01-10
# 817       JO0008     INV818          2018-12-31  2019-02-01 2019-02-04
# 568       JO0009     INV569          2019-01-02  2019-01-17 2019-01-14
#
#       Invoice Amount  Due_Amount   status  delay
# 507            85000       85000    Fully     26
# 221            15000       15000    Fully     -5
# 1099           70000       65500  Partial     -5
# 817            20000       14000  Partial      3
# 568            50000       41000  Partial     -3

# %%
test_data = df[df.clear_date.isnull()].reset_index()
test_data.drop(columns=['index'],inplace=True)
test_data
# Out:
# Empty DataFrame
# Columns: [cust_number, Invoice_No, invoice_create_date, due_in_date, clear_date, Invoice Amount, Due_Amount, status, delay]
# Index: []

# %%
ts = test_data.copy()

# %%
y_test = test_data["delay"]
y_test
# Out:
# Series([], Name: delay, dtype: int64)

# %%
x_test = test_data.iloc[:,:-1].copy()
x_test
# Out:
# Empty DataFrame
# Columns: [cust_number, Invoice_No, invoice_create_date, due_in_date, clear_date, Invoice Amount, Due_Amount, status]
# Index: []

# %%
train_data2 = df[df.clear_date.notnull()].reset_index() #train set on non-null clear date
train_data2.drop(columns=['index'],inplace=True)
train_data2
# Out:
#      cust_number Invoice_No invoice_create_date due_in_date clear_date  \
# 0         JO0008     INV508          2018-12-30  2019-02-03 2019-03-01
# 1         JO0002     INV222          2018-12-30  2019-01-14 2019-01-09
# 2         JO0010    INV1100          2018-12-31  2019-01-15 2019-01-10
# 3         JO0008     INV818          2018-12-31  2019-02-01 2019-02-04
# 4         JO0009     INV569          2019-01-02  2019-01-17 2019-01-14
# ...          ...        ...                 ...         ...        ...
# 1198      JO0003    INV1093          2020-02-26  2020-03-12 2020-03-12
# 1199      JO0004     INV124          2020-02-26  2020-03-12 2020-03-16
# 1200      JO0007     INV347          2020-02-26  2020-03-12 2020-03-10
# 1201      JO0003      INV23          2020-02-26  2020-03-12 2020-03-09
# 1202      JO0010      INV70          2020-02-26  2020-03-12 2020-03-09
#
#       Invoice Amount  Due_Amount   status  delay
# 0              85000       85000    Fully     26
# 1              15000       15000    Fully     -5
# 2              70000       65500  Partial     -5
# 3              20000       14000  Partial      3
# 4              50000       41000  Partial     -3
# ...              ...         ...      ...    ...
# 1198           35000       26500  Partial      0
# 1199           35000       35000    Fully      4
# 1200           45000       42000  Partial     -2
# 1201           40000       34000  Partial     -3
# 1202           20000       13000  Partial     -3
#
# [1203 rows x 9 columns]

# %%
# Making use of offset to find date 1.5 months prior to 2020-02-27
x = train_data2['invoice_create_date'].iloc[-1] - pd.DateOffset(months=1, days=15)
y = train_data2['invoice_create_date'].loc[train_data2['invoice_create_date'] <= x].iloc[-1]
print(y) 
train_data2['invoice_create_date'].loc[train_data2['invoice_create_date'] == y].last_valid_index()
# Out:
# 2020-01-10 00:00:00
# 1078

# %%
# dataframe for val2
val2 = train_data2.iloc[41779: , :].copy()
val2.reset_index(drop=True,inplace=True)
val2.shape
# Out:
# (0, 9)

# %%
train_data1 = pd.concat([train_data2, val2]).drop_duplicates(keep=False)
train_data1
# Out:
#      cust_number Invoice_No invoice_create_date due_in_date clear_date  \
# 0         JO0008     INV508          2018-12-30  2019-02-03 2019-03-01
# 1         JO0002     INV222          2018-12-30  2019-01-14 2019-01-09
# 2         JO0010    INV1100          2018-12-31  2019-01-15 2019-01-10
# 3         JO0008     INV818          2018-12-31  2019-02-01 2019-02-04
# 4         JO0009     INV569          2019-01-02  2019-01-17 2019-01-14
# ...          ...        ...                 ...         ...        ...
# 1198      JO0003    INV1093          2020-02-26  2020-03-12 2020-03-12
# 1199      JO0004     INV124          2020-02-26  2020-03-12 2020-03-16
# 1200      JO0007     INV347          2020-02-26  2020-03-12 2020-03-10
# 1201      JO0003      INV23          2020-02-26  2020-03-12 2020-03-09
# 1202      JO0010      INV70          2020-02-26  2020-03-12 2020-03-09
#
#       Invoice Amount  Due_Amount   status  delay
# 0              85000       85000    Fully     26
# 1              15000       15000    Fully     -5
# 2              70000       65500  Partial     -5
# 3              20000       14000  Partial      3
# 4              50000       41000  Partial     -3
# ...              ...         ...      ...    ...
# 1198           35000       26500  Partial      0
# 1199           35000       35000    Fully      4
# 1200           45000       42000  Partial     -2
# 1201           40000       34000  Partial     -3
# 1202           20000       13000  Partial     -3
#
# [1203 rows x 9 columns]

# %%
x2 = train_data1['invoice_create_date'].iloc[-1] - pd.DateOffset(months=1, days=15)
y2 = train_data1['invoice_create_date'].loc[train_data1['invoice_create_date'] <= x2].iloc[-1]
print(y2)
train_data1['invoice_create_date'].loc[train_data1['invoice_create_date'] == y2].last_valid_index()
# Out:
# 2020-01-10 00:00:00
# 1078

# %%
val1 = train_data1.iloc[38486: , :].copy()
val1.reset_index(drop=True,inplace=True)
val1
# Out:
# Empty DataFrame
# Columns: [cust_number, Invoice_No, invoice_create_date, due_in_date, clear_date, Invoice Amount, Due_Amount, status, delay]
# Index: []

# %%
train_data = pd.concat([train_data1, val1]).drop_duplicates(keep=False)
train_data
# Out:
#      cust_number Invoice_No invoice_create_date due_in_date clear_date  \
# 0         JO0008     INV508          2018-12-30  2019-02-03 2019-03-01
# 1         JO0002     INV222          2018-12-30  2019-01-14 2019-01-09
# 2         JO0010    INV1100          2018-12-31  2019-01-15 2019-01-10
# 3         JO0008     INV818          2018-12-31  2019-02-01 2019-02-04
# 4         JO0009     INV569          2019-01-02  2019-01-17 2019-01-14
# ...          ...        ...                 ...         ...        ...
# 1198      JO0003    INV1093          2020-02-26  2020-03-12 2020-03-12
# 1199      JO0004     INV124          2020-02-26  2020-03-12 2020-03-16
# 1200      JO0007     INV347          2020-02-26  2020-03-12 2020-03-10
# 1201      JO0003      INV23          2020-02-26  2020-03-12 2020-03-09
# 1202      JO0010      INV70          2020-02-26  2020-03-12 2020-03-09
#
#       Invoice Amount  Due_Amount   status  delay
# 0              85000       85000    Fully     26
# 1              15000       15000    Fully     -5
# 2              70000       65500  Partial     -5
# 3              20000       14000  Partial      3
# 4              50000       41000  Partial     -3
# ...              ...         ...      ...    ...
# 1198           35000       26500  Partial      0
# 1199           35000       35000    Fully      4
# 1200           45000       42000  Partial     -2
# 1201           40000       34000  Partial     -3
# 1202           20000       13000  Partial     -3
#
# [1203 rows x 9 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1203 entries, 0 to 1202
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   cust_number          1203 non-null   object
#  1   Invoice_No           1203 non-null   object
#  2   invoice_create_date  1203 non-null   datetime64[ns]
#  3   due_in_date          1203 non-null   datetime64[ns]
#  4   clear_date           1203 non-null   datetime64[ns]
#  5   Invoice Amount       1203 non-null   int64
#  6   Due_Amount           1203 non-null   int64
#  7   status               1203 non-null   object
#  8   delay                1203 non-null   int64
# dtypes: datetime64[ns](3), int64(3), object(3)
# memory usage: 94.0+ KB

# %% [markdown]
# # EDA on train set

# %%
train_data.cust_number.value_counts()
# Out:
# JO0002    121
# JO0001    121
# JO0003    121
# JO0008    120
# JO0010    120
# JO0009    120
# JO0005    120
# JO0006    120
# JO0007    120
# JO0004    120
# Name: cust_number, dtype: int64

# %%
len(dict(train_data.cust_number.value_counts()))
# Out:
# 10

# %%
train_data.clear_date.min()
# Out:
# Timestamp('2019-01-09 00:00:00')

# %%
train_data.clear_date.max()
# Out:
# Timestamp('2020-04-30 00:00:00')

# %%
clear_month = train_data.clear_date.dt.month
clear_month.value_counts()
# Out:
# 2     140
# 3     126
# 5     115
# 4     104
# 11    102
# 10    100
# 7      95
# 8      89
# 12     89
# 1      86
# 9      86
# 6      71
# Name: clear_date, dtype: int64

# %%
sns.countplot(x=clear_month, palette="hls")
# Out:
# <AxesSubplot:xlabel='clear_date', ylabel='count'>
